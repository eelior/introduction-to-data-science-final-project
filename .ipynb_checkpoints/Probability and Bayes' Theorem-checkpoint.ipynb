# %% [markdown]
# Auther: Elior Buskila
#
# ID: 205493323

# %% [markdown]
# # <ins><center>First Notebook</center></ins>

# %% [markdown]
# ## Probability and Bayes' Theorem

# %% [markdown]
# ### Q1.1

# %% [markdown]
# - About 1/125 of births are non-identical twins and 1/300 of births are identical twins. Elvis had a twin brother who died in childbirth. What is the probability that Elvis was identical twin? (It can be assumed that the probability of having a son and a daughter is equal to 1/2)

# %% [markdown]
# $ P(identicalTwinBrother|twinBrother)= \frac{P(identicalTwinBrother) * P(twinBrother|identicalTwinBrother)}{P(twinBrother)} = \frac{(\frac{17}{1500} * \frac{5}{17}) * 1}{\frac{17}{1500}} = \frac{5}{17} = 0.294... $

# %% [markdown]
# ### Q1.2

# %% [markdown]
# - There are two bowls of cookies. Bowl 1 has 10 almond cookies and 30 chocolate chip cookies. In bowl 2 there is 20 almond cookies and 20 chocolate chip cookies. Eric chose a bowl at random and chose a cookie from it at random.
# The cookie selected is chocolate. What is the probability that Eric chose Bowl 1?

# %% [markdown]
# $ P(bowl1|choco)= \frac{P(bowl1) * P(choco|bowl1)}{P(choco)} = \frac{\frac{1}{2} * \frac{3}{4}}{\frac{1}{2} * \frac{3}{4} + \frac{1}{2} * \frac{1}{2}} = \frac{3}{5} = 0.6 $

# %% [markdown]
# ### Q2

# %% [markdown]
# - In 1995, M&M added the color blue. Before this year, the color distribution
# The M&M bag looks like this:
# 30% Brown, 20% Yellow, 20% Red, 10% Green, 10% Orange, 10% Tan
# As of 1995, the distribution looks like this:
# 24% Blue, 20% Green, 16% Orange, 14% Yellow, 13% Red, 13% Brown.
# Your friend has 2 M&M bags, one from 1994 and one from 1996 and he is not willing to reveal it to you Which bag belongs to which year. But he gives you one candy from each bag. One candy is yellow and one is green. What's the chance that the yellow candy came from the 1994 bag?

# %% [markdown]
# $ P(oldBag|yellowCandy)= \frac{P(oldBag) * P(yellowCandy|oldBag)}{P(yellowCandy)} = \frac{\frac{1}{2} * \frac{1}{5}}{\frac{1}{2} * \frac{1}{5} + \frac{1}{2} * \frac{14}{100}} = \frac{10}{17} = 0.588... $

# %% [markdown]
# ### Q3.1

# %% [markdown]
# - You went to the doctor following an ingrown toenail. The doctor randomly selected you to perform a blood test checking for swine flu. It is statistically known that this flu affects 1 in 10,000 people in the population. The test is 99 percent accurate in the sense that the probability of a positive false is% 1. This means that the test is classifing by mistake a healthy person as a sick person is 1 percent. The probability of negative false is 0 - no chance that the test will tell a person with swine flu that he is healthy. In the test you came out positive (you have the flu). What is the probability that you have swine flu?

# %% [markdown]
# $ P(sick|positiveTest)= \frac{P(sick) * P(positiveTest|sick)}{P(posistiveTest)} = \frac{\frac{1}{10^4} * \frac{99}{10^2}}{\frac{1}{10^4} * \frac{99}{10^2} + \frac{9999}{10^4} * \frac{1}{10^2}} = \frac{1}{102} $

# %% [markdown]
# ### Q3.2

# %% [markdown]
# - Suppose you have recently returned from Thailand and you know that 1 in 200 people who have recently returned from Thailand have returned with swine flu. Given the same situation as in question 3.1, what is the (corrected) probability that you have swine flu?

# %% [markdown]
# $ P(sick|positiveTest)= \frac{P(sick) * P(positiveTest|sick)}{P(posistiveTest)} = \frac{\frac{1}{200} * \frac{99}{100}}{\frac{1}{200} * \frac{99}{100} + \frac{199}{200} * \frac{1}{100}} = \frac{149}{10^4} = 0.0149 $

# %% [markdown]
# ## Random Variables

# %% [markdown]
# ### Q1

# %% [markdown]
# - Roi is playing a dice game with Yael. Roi will roll 2 six-sided dice, and if the sum of the dice is divisible by 3, he will win \\$6. If the sum is not divisible by 3, he will lose \\$3. What is Roi’s expected value of playing this game?

# %% [markdown]
# There is $ 6^2 $ different combinations to rolling a pair dices.
# From them, 12 combinations will give us a sum that divides by 3.
# So $ \frac{12}{6^2} = \frac{1}{3} $ is the probability of winning \\$3, and completing it, $ 1 - \frac{1}{3} = \frac{2}{3} $ is the probability of losing \\$3.

# %% [markdown]
# So Roi's expected value of playing this game:
#
# $ E(x) = P(win) * 6 + P(lose) * (-3) = \frac{1}{3} * 6 + \frac{2}{3} * (-3) = 0 $

# %% [markdown]
# ### Q2

# %% [markdown]
# - Sharon has challenged Alex to a round of Marker Mixup. Marker Mixup is a game where there is a bag of 5 red markers numbered 1 through 5, and another bag with 5 green markers numbered 6 through 10. Alex will grab 1 marker from each bag, and if the 2 markers add up to more than 12, he will win \\$5. If the sum is exactly 12, he will break even, and If the sum is less than 12, he will
# lose 6$. What is Alex's expected value of playing Marker Mixup?

# %% [markdown]
# There is $ 5^2 $ different combinations for drawing 2 markers.
# From them, 15 combinations will give us a sum of less then 12, 4 combinations of exactly 4, and 6 combinations of more then 12.

# %% [markdown]
# So Alex's expected value of playing this game:
#
# $ E(x) = P(more) * 5 + P(even) * 0 + P(less) * (-6) = \frac{6}{25} * 5 + \frac{4}{25} * 0 + \frac{15}{25} * (-6) = -\frac{12}{5} = -2.4 $

# %% [markdown]
# ### Q3

# %% [markdown]
# - A division of a company has 200 employees, 40%, percent of which are male. Each month, the company randomly selects 8 of these employees to have lunch with the CEO. What are the mean and standard deviation of the number of males selected each month?

# %% [markdown]
# $ \mu = 0.4 * 8 = 3.2 $

# %% [markdown]
# $ x \in [0,8] $
#
# $ \sigma =  \sqrt{\frac{1}{9}*\sum_{i=0}^8{(x_i - 3.2)^2}} = 2.703... $

# %% [markdown]
# ### Q4

# %% [markdown]
# - Different dealers may sell the same car for different prices. The sale prices for a particular car are normally distributed with a mean and standard deviation of \\$26,000 and \\$2,000, respectively. Suppose we select one of these cars at random. Let X = the sale price (in thousands of dollars) for the selected car. Find P(26<X<30).

# %% [markdown]
# Converting to z-scores:
#
# Z score for x = 26 $ z = \frac{26 - 26}{2} = 0 $.
#
# Z score for x = 30 $ z = \frac{30 - 26}{2} = 2 $.

# %% [markdown]
# Calculating the probabilty by z-table:
#
# $ P(x<0) - P(x>2) = 0.5 - 0.02275 = 0.47725 $
#
# $P(0<x<2) = 0.47725 $

# %% [markdown]
# ### Q5

# %% [markdown]
# - Given the following distribution, what is P(x>3)?
# <img width=300 src="files/images/NB1-1.png">

# %% [markdown]
# The integral of the the area from x>3 can be simply calculated by the area of the triangle:

# %% [markdown]
# $ P(x>3) = \frac{0.4 * |3-5|}{2} = \frac{2}{5} = 0.4 $

# %% [markdown]
# ### Q6

# %% [markdown]
# - A company has 500 employees, and 60% of them have children. Suppose that we randomly select 4 of these employees. What is the probability that exactly 3 of the 4 employees selected have children?

# %% [markdown]
# $ C^4_3 = \binom{4}{3} = \frac{4!}{3!(4-3)!} = 4 $

# %% [markdown]
# $ Parents = 500 * 0.6 = 300 $

# %% [markdown]
# $ (P(parent))^3 * P(notParent) * C^4_3 = \frac{300}{500} * \frac{299}{499} * \frac{298}{498} * \frac{200}{497} * 4 = 0.34629\dots  $

# %% [markdown]
# ### Q7

# %% [markdown]
# - Look at the next Graph. What is the expected value of X?

# %% [markdown]
# <img width=300 src="files/images/NB1-2.png">

# %% [markdown]
# $ E(x) = (-10)*0.1 + (-5)*0.35 + 0*0.1 + 5*0.35 + 10*0.1 = 0 $
