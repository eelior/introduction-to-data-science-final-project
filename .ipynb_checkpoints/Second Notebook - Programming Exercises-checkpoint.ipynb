# %% [markdown]
# Auther: Elior Buskila
#
# ID: 205493323

# %% [markdown]
# # <ins><center>Second Notebook</center></ins>

# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# ### Q1

# %% [markdown]
# - Write a program in Python that gets a number in base 10 and prints the number in all the other bases (base 2, base 8 and base 16).

# %%
def deciamlToOtherBases(origin): 
    def toLetter(num):
        if (num >= 0 and num <= 9): 
            return chr(num + ord('0')); 
        else: 
            return chr(num - 10 + ord('A')); 
    
    base = [2,8,16];
    res = ["","",""];
    
    for i in range(len(base)):
        num = origin;
        while (num > 0): 
            res[i] = toLetter(num % base[i]) + res[i]; 
            num = int(num / base[i]);
    
    print(f"""
        The representation of {origin} for bases:
        binary - {res[0]}
        Octal - {res[1]}
        hexadeciaml - {res[2]}
        """);

# %%
## deciamlToOtherBases Test:
deciamlToOtherBases(98797703254523);
# Out:
#         The representation of 98797703254523 for bases:
#         binary - 10110011101101100100010000000011101000111111011
#         Octal - 2635544200350773
#         hexadeciaml - 59DB2201D1FB

# %% [markdown]
# ### Q2

# %% [markdown]
# - Load the DATASET to the notebook and answer the following questions:

# %%
import pandas as pd
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %% [markdown]
# ### Q2.1

# %% [markdown]
# - How many movies have the title "Hamlet"?

# %%
len(cast[cast.title == "Hamlet"])
# Out:
# 299

# %% [markdown]
# ### Q2.2

# %% [markdown]
# - List all of the "Treasure Island" movies from earliest to most recent.

# %%
cast[cast.title == "Treasure Island"].sort_values(by='year')
# Out:
#                    title  year                  name     type  \
# 1312766  Treasure Island  1918       Herschel Mayall    actor
# 3280557  Treasure Island  1918    Eleanor Washington  actress
# 3046750  Treasure Island  1918      Violet Radcliffe  actress
# 1167783  Treasure Island  1918           Raymond Lee    actor
# 1195421  Treasure Island  1918          Elmo Lincoln    actor
# ...                  ...   ...                   ...      ...
# 1663860  Treasure Island  1999  Victor Raider-Wexler    actor
# 1731182  Treasure Island  1999  Scot Thomas Robinson    actor
# 1813707  Treasure Island  1999        Richard Schave    actor
# 2710458  Treasure Island  1999    Stephanie Ittleson  actress
# 815338   Treasure Island  1999          Rio Hackford    actor
#
#                 character     n
# 1312766   Prologue Player   NaN
# 3280557   Prologue Player   NaN
# 3046750  Long John Silver   3.0
# 1167783          Bit Role   NaN
# 1195421   Prologue Player   NaN
# ...

# %% [markdown]
# ### Q2.3

# %% [markdown]
# - How many roles were credited in the silent 1921 version of Hamlet?

# %%
len(cast[(cast.title == "Hamlet") & (cast.year == 1921)])
# Out:
# 9

# %% [markdown]
# ### Q2.4

# %% [markdown]
# - Use groupby() to plot the number of "Hamlet" films made each decade

# %%
hamlets = cast[cast.title == "Hamlet"];
hamlets.groupby(hamlets.year // 10 * 10).size()
# Out:
# year
# 1910    28
# 1920     9
# 1940    25
# 1950     1
# 1960    57
# 1970    19
# 1980     3
# 1990    84
# 2000    55
# 2010    18
# dtype: int64

# %% [markdown]
# ### Q2.5

# %% [markdown]
# - How many leading (n=1) roles were available to actors, and how many to
# actresses, in each year of the 1950s?

# %%
leading = cast[cast.year // 10 == 195]
leading = leading[leading.n == 1]
leading.groupby(['year', 'type']).size()
# Out:
# year  type
# 1950  actor      604
#       actress    271
# 1951  actor      633
#       actress    272
# 1952  actor      591
#       actress    284
# 1953  actor      634
#       actress    290
# 1954  actor      626
#       actress    298
# 1955  actor      606
#       actress    264
# 1956  actor      614
#       actress    288
# 1957  actor      708
#       actress    284
# 1958  actor      694
#       actress    275
# 1959  actor      678
#       actress    287
# dtype: int64

# %% [markdown]
# ### Q2.6

# %% [markdown]
# - List the 10 actors/actresses that have the most leading roles (n=1) since the 1990's.

# %%
top = cast[(cast.n == 1) & (cast.year >= 1990)]
top = top.groupby(['name']).size().sort_values(ascending=False)
top.head(10)
# Out:
# name
# Mohanlal              126
# Mammootty             118
# Akshay Kumar           87
# Jayaram                76
# Andy Lau               72
# Ajay Devgn             69
# Eric Roberts           68
# Amitabh Bachchan       68
# Nagarjuna Akkineni     60
# Dilip                  59
# dtype: int64

# %% [markdown]
# ### Q2.7

# %% [markdown]
# - List, in order by year, each of the films in which Frank Oz has played more than 1 role

# %%
franks = cast[cast.name == 'Frank Oz']
franks = franks.groupby(['year','title']).size()
franks[franks > 1]
# Out:
# year  title
# 1979  The Muppet Movie                            8
# 1981  An American Werewolf in London              2
#       The Great Muppet Caper                      6
# 1982  The Dark Crystal                            2
# 1984  The Muppets Take Manhattan                  7
# 1985  Sesame Street Presents: Follow that Bird    3
# 1992  The Muppet Christmas Carol                  7
# 1996  Muppet Treasure Island                      4
# 1999  Muppets from Space                          4
#       The Adventures of Elmo in Grouchland        3
# dtype: int64
